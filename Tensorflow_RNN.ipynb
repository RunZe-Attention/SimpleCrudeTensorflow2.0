# %%
import tensorflow as tf
import numpy as np

# %%
class DataLoader():
    def __init__(self):
        path = tf.keras.utils.get_file('nietzsche.txt',
            origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
        with open(path, encoding='utf-8') as f:
            self.raw_text = f.read().lower()
        self.chars = sorted(list(set(self.raw_text)))
        self.char_indices = dict((c, i) for i, c in enumerate(self.chars))
        self.indices_char = dict((i, c) for i, c in enumerate(self.chars))
        self.text = [self.char_indices[c] for c in self.raw_text]

    def get_batch(self, seq_length, batch_size):# 每次训练一批样本 可以取均值,避免单个离群值带来的偏差
        seq = []
        next_char = []
        for i in range(batch_size):
            index = np.random.randint(0, len(self.text) - seq_length)
            seq.append(self.text[index:index+seq_length])
            next_char.append(self.text[index+seq_length])
        return np.array(seq), np.array(next_char)       # [batch_size, seq_length], [batch_size]

# %%
class RNN(tf.keras.Model):
    def __init__(self,num_chars,batch_size,seq_length):
        super().__init__()
        self.num_chars = num_chars
        self.batch_size = batch_size
        self.seq_length = seq_length
        self.cell = tf.keras.layers.LSTMCell(units = 256)
        self.dense = tf.keras.layers.Dense(units = self.num_chars)
        
    def call(self,inputs,from_logits = False):
        inputs = tf.one_hot(inputs,depth = self.num_chars)
        state = self.cell.get_initial_state(batch_size = self.batch_size,dtype = tf.float32)
        for t in range(self.seq_length):
            output,state = self.cell(inputs[:,t,:],state)
        
        logits = self.dense(output)
        if from_logits:
            return logits
        else:
            return tf.nn.softmax(logits)
        
    def predict(self, inputs, temperature=1.):
        batch_size, _ = tf.shape(inputs)
        logits = self(inputs, from_logits=True)                         # 调用训练好的RNN模型，预测下一个字符的概率分布
        prob = tf.nn.softmax(logits / temperature).numpy()              # 使用带 temperature 参数的 softmax 函数获得归一化的概率分布值
        return np.array([np.random.choice(self.num_chars, p=prob[i, :]) # 使用 np.random.choice 函数，
                         for i in range(batch_size.numpy())])

# %%
num_batches = 1000  # 训练1000轮
seq_length = 40     # 序列长度40
batch_size = 50     # 每次的批次为50
learning_rate = 1e-3 #学习率

# %%
data_loader = DataLoader()
model = RNN(num_chars = len(data_loader.chars),batch_size = batch_size,seq_length = seq_length)
optimizer = tf.keras.optimizers.Adam(learning_rate = learning_rate)
for batch_index in range(num_batches):
    X,y = data_loader.get_batch(seq_length,batch_size)
    with tf.GradientTape() as tape:
        y_pred = model(X)
        loss = tf.keras.losses.sparse_categorical_crossentropy(y_true = y,y_pred = y_pred)
        loss = tf.reduce_mean(loss)
        print("batch_index %d,loss %f" % (batch_index,loss.numpy()))
    grads = tape.gradient(loss,model.variables)
    optimizer.apply_gradients(grads_and_vars = zip(grads,model.variables))
# Out:
# batch_index 0,loss 4.046930
# batch_index 1,loss 4.023759
# batch_index 2,loss 4.012225
# batch_index 3,loss 3.974755
# batch_index 4,loss 3.959831
# batch_index 5,loss 3.888484
# batch_index 6,loss 3.741380
# batch_index 7,loss 3.456250
# batch_index 8,loss 3.312930
# batch_index 9,loss 3.769981
# batch_index 10,loss 3.195498
# batch_index 11,loss 3.174865
# batch_index 12,loss 3.027397
# batch_index 13,loss 3.234847
# batch_index 14,loss 3.376699
# batch_index 15,loss 3.104056
# batch_index 16,loss 3.066119
# batch_index 17,loss 3.109254
# batch_index 18,loss 3.186244
# batch_index 19,loss 2.985195
# batch_index 20,loss 3.010646
# batch_index 21,loss 3.104559
# batch_index 22,loss 3.439594
# batch_index 23,loss 3.189495
# batch_index 24,loss 3.137863
# batch_index 25,loss 2.824996
# batch_index 26,loss 2.992568
# batch_index 27,loss 2.920878
# batch_index 28,loss 2.891249
# batch_index 29,loss 3.231491
# batch_index 30,loss 3.112705
# batch_index 31,loss 3.126866
# batch_index 32,loss 3.228296
# batch_index 33,loss 2.992580
# batch_index 34,loss 3.151580
# batch_index 35,loss 3.026504
# batch_index 36,loss 3.299308
# batch_index 37,loss 3.025554
# batch_index 38,loss 3.209913
# batch_index 39,loss 2.961375
# batch_index 40,loss 2.815440
# batch_index 41,loss 2.920893
# batch_index 42,loss 2.937477
# batch_index 43,loss 3.120627
# batch_index 44,loss 3.116333
# batch_index 45,loss 2.878384
# batch_index 46,loss 3.207788
# batch_index 47,loss 3.002044
# batch_index 48,loss 2.930299
# batch_index 49,loss 3.089049
# batch_index 50,loss 2.935019
# batch_index 51,loss 3.370251
# batch_index 52,loss 2.879338
# batch_index 53,loss 2.958159
# batch_index 54,loss 3.039876
# batch_index 55,loss 3.059525
# batch_index 56,loss 2.975926
# batch_index 57,loss 2.944715
# batch_index 58,loss 2.897253
# batch_index 59,loss 3.093708
# batch_index 60,loss 3.310909
# batch_index 61,loss 2.890067
# batch_index 62,loss 3.174580
# batch_index 63,loss 2.922266
# batch_index 64,loss 2.796508
# batch_index 65,loss 3.031048
# batch_index 66,loss 3.179237
# batch_index 67,loss 3.026614
# batch_index 68,loss 3.072900
# batch_index 69,loss 2.957294
# batch_index 70,loss 2.899082
# batch_index 71,loss 2.914314
# batch_index 72,loss 2.960074
# batch_index 73,loss 2.986103
# batch_index 74,loss 2.959699
# batch_index 75,loss 3.055418
# batch_index 76,loss 3.130015
# batch_index 77,loss 2.882441
# batch_index 78,loss 3.200253
# batch_index 79,loss 3.056833
# batch_index 80,loss 3.077545
# batch_index 81,loss 3.021805
# batch_index 82,loss 3.023733
# batch_index 83,loss 2.913523
# batch_index 84,loss 2.964999
# batch_index 85,loss 2.884320
# batch_index 86,loss 3.197686
# batch_index 87,loss 3.102113
# batch_index 88,loss 3.093525
# batch_index 89,loss 2.950487
# batch_index 90,loss 3.028800
# batch_index 91,loss 3.123142
# batch_index 92,loss 2.893449
# batch_index 93,loss 3.149444
# batch_index 94,loss 2.937449
# batch_index 95,loss 3.069139
# batch_index 96,loss 3.141478
# batch_index 97,loss 2.886169
# batch_index 98,loss 2.903299
# batch_index 99,loss 3.085734
# batch_index 100,loss 3.078920
# batch_index 101,loss 3.036651
# batch_index 102,loss 3.063980
# batch_index 103,loss 2.950548
# batch_index 104,loss 2.842160
# batch_index 105,loss 2.855115
# batch_index 106,loss 2.969049
# batch_index 107,loss 3.173857
# batch_index 108,loss 3.218248
# batch_index 109,loss 3.154270
# batch_index 110,loss 2.764904
# batch_index 111,loss 3.012514
# batch_index 112,loss 3.404856
# batch_index 113,loss 3.136662
# batch_index 114,loss 3.297543
# batch_index 115,loss 2.863180
# batch_index 116,loss 2.975701
# batch_index 117,loss 2.956693
# batch_index 118,loss 2.962133
# batch_index 119,loss 3.015468
# batch_index 120,loss 2.898639
# batch_index 121,loss 2.917508
# batch_index 122,loss 3.000674
# batch_index 123,loss 3.018153
# batch_index 124,loss 3.033332
# batch_index 125,loss 3.128325
# batch_index 126,loss 3.094432
# batch_index 127,loss 2.875179
# batch_index 128,loss 3.051466
# batch_index 129,loss 2.840982
# batch_index 130,loss 3.054785
# batch_index 131,loss 3.087527
# batch_index 132,loss 2.963031
# batch_index 133,loss 2.834339
# batch_index 134,loss 2.898920
# batch_index 135,loss 2.976740
# batch_index 136,loss 3.075523
# batch_index 137,loss 3.064874
# batch_index 138,loss 2.955774
# batch_index 139,loss 3.172740
# batch_index 140,loss 2.772856
# batch_index 141,loss 3.109088
# batch_index 142,loss 2.714530
# batch_index 143,loss 3.040927
# batch_index 144,loss 3.157834
# batch_index 145,loss 3.028588
# batch_index 146,loss 3.086510
# batch_index 147,loss 3.061320
# batch_index 148,loss 2.934429
# batch_index 149,loss 2.950842
# batch_index 150,loss 2.884938
# batch_index 151,loss 2.917148
# batch_index 152,loss 3.026026
# batch_index 153,loss 2.876325
# batch_index 154,loss 2.864599
# batch_index 155,loss 2.863806
# batch_index 156,loss 3.010110
# batch_index 157,loss 3.246260
# batch_index 158,loss 2.931530
# batch_index 159,loss 3.018627
# batch_index 160,loss 3.031487
# batch_index 161,loss 2.972098
# batch_index 162,loss 2.989801
# batch_index 163,loss 3.089046
# batch_index 164,loss 3.018490
# batch_index 165,loss 3.001009
# batch_index 166,loss 3.074388
# batch_index 167,loss 3.010569
# batch_index 168,loss 2.881850
# batch_index 169,loss 2.923436
# batch_index 170,loss 2.918173
# batch_index 171,loss 2.934724
# batch_index 172,loss 3.077896
# batch_index 173,loss 2.850850
# batch_index 174,loss 3.094281
# batch_index 175,loss 3.055129
# batch_index 176,loss 2.978862
# batch_index 177,loss 2.875065
# batch_index 178,loss 2.968830
# batch_index 179,loss 3.055146
# batch_index 180,loss 3.180923
# batch_index 181,loss 3.248761
# batch_index 182,loss 2.952295
# batch_index 183,loss 2.917220
# batch_index 184,loss 3.202715
# batch_index 185,loss 3.021981
# batch_index 186,loss 3.034429
# batch_index 187,loss 2.906376
# batch_index 188,loss 2.679310
# batch_index 189,loss 3.179295
# batch_index 190,loss 2.996500
# batch_index 191,loss 2.815811
# batch_index 192,loss 2.973157
# batch_index 193,loss 3.063259
# batch_index 194,loss 3.034754
# batch_index 195,loss 3.002519
# batch_index 196,loss 3.055302
# batch_index 197,loss 2.842004
# batch_index 198,loss 2.794330
# batch_index 199,loss 2.824710
# batch_index 200,loss 3.111523
# batch_index 201,loss 3.499276
# batch_index 202,loss 2.909859
# batch_index 203,loss 3.057837
# batch_index 204,loss 2.974339
# batch_index 205,loss 3.059526
# batch_index 206,loss 2.861471
# batch_index 207,loss 2.950635
# batch_index 208,loss 3.230679
# batch_index 209,loss 2.908228
# batch_index 210,loss 2.968615
# batch_index 211,loss 3.179410
# batch_index 212,loss 2.832440
# batch_index 213,loss 2.930633
# batch_index 214,loss 2.923727
# batch_index 215,loss 2.991565
# batch_index 216,loss 3.087300
# batch_index 217,loss 2.766357
# batch_index 218,loss 2.999618
# batch_index 219,loss 3.055470
# batch_index 220,loss 2.896063
# batch_index 221,loss 2.755220
# batch_index 222,loss 2.805480
# batch_index 223,loss 3.056281
# batch_index 224,loss 2.902817
# batch_index 225,loss 2.988868
# batch_index 226,loss 2.763094
# batch_index 227,loss 2.974831
# batch_index 228,loss 3.116584
# batch_index 229,loss 2.756495
# batch_index 230,loss 3.037520
# batch_index 231,loss 2.639003
# batch_index 232,loss 2.756625
# batch_index 233,loss 3.182765
# batch_index 234,loss 2.975078
# batch_index 235,loss 2.730687
# batch_index 236,loss 2.790483
# batch_index 237,loss 2.792861
# batch_index 238,loss 2.700853
# batch_index 239,loss 2.832243
# batch_index 240,loss 2.801795
# batch_index 241,loss 2.818719
# batch_index 242,loss 3.150795
# batch_index 243,loss 3.122705
# batch_index 244,loss 2.848919
# batch_index 245,loss 3.073259
# batch_index 246,loss 2.958486
# batch_index 247,loss 3.016664
# batch_index 248,loss 2.768613
# batch_index 249,loss 2.965894
# batch_index 250,loss 3.290345
# batch_index 251,loss 2.974915
# batch_index 252,loss 2.981709
# batch_index 253,loss 3.060041
# batch_index 254,loss 2.762131
# batch_index 255,loss 2.851318
# batch_index 256,loss 2.804243
# batch_index 257,loss 2.936240
# batch_index 258,loss 3.203173
# batch_index 259,loss 3.205028
# batch_index 260,loss 2.960493
# batch_index 261,loss 2.930058
# batch_index 262,loss 3.030595
# batch_index 263,loss 3.003440
# batch_index 264,loss 3.084292
# batch_index 265,loss 2.997853
# batch_index 266,loss 2.883386
# batch_index 267,loss 2.990138
# batch_index 268,loss 2.773518
# batch_index 269,loss 2.836925
# batch_index 270,loss 2.810760
# batch_index 271,loss 2.737751
# batch_index 272,loss 3.106416
# batch_index 273,loss 2.877486
# batch_index 274,loss 2.973832
# batch_index 275,loss 2.981609
# batch_index 276,loss 2.714243
# batch_index 277,loss 2.823972
# batch_index 278,loss 2.827854
# batch_index 279,loss 2.732025
# batch_index 280,loss 2.975671
# batch_index 281,loss 2.864226
# batch_index 282,loss 2.801941
# batch_index 283,loss 2.881842
# batch_index 284,loss 2.798435
# batch_index 285,loss 3.143430
# batch_index 286,loss 2.875626
# batch_index 287,loss 2.619751
# batch_index 288,loss 3.037164
# batch_index 289,loss 2.388178
# batch_index 290,loss 3.079540
# batch_index 291,loss 2.711489
# batch_index 292,loss 2.895314
# batch_index 293,loss 2.693599
# batch_index 294,loss 2.480186
# batch_index 295,loss 3.090853
# batch_index 296,loss 2.703168
# batch_index 297,loss 2.688894
# batch_index 298,loss 2.977446
# batch_index 299,loss 2.895598
# batch_index 300,loss 2.617867
# batch_index 301,loss 2.795693
# batch_index 302,loss 2.629225
# batch_index 303,loss 2.727459
# batch_index 304,loss 2.603723
# batch_index 305,loss 2.881585
# batch_index 306,loss 2.754404
# batch_index 307,loss 3.038110
# batch_index 308,loss 2.769368
# batch_index 309,loss 2.799619
# batch_index 310,loss 3.032290
# batch_index 311,loss 2.816469
# batch_index 312,loss 2.643605
# batch_index 313,loss 2.963919
# batch_index 314,loss 2.817920
# batch_index 315,loss 3.159917
# batch_index 316,loss 2.757275
# batch_index 317,loss 2.655753
# batch_index 318,loss 2.821838
# batch_index 319,loss 2.967553
# batch_index 320,loss 2.928475
# batch_index 321,loss 2.764495
# batch_index 322,loss 2.955098
# batch_index 323,loss 2.825151
# batch_index 324,loss 2.671331
# batch_index 325,loss 2.754060
# batch_index 326,loss 2.812072
# batch_index 327,loss 2.738322
# batch_index 328,loss 2.888583
# batch_index 329,loss 2.717769
# batch_index 330,loss 2.659727
# batch_index 331,loss 2.552917
# batch_index 332,loss 2.571999
# batch_index 333,loss 2.788154
# batch_index 334,loss 2.945688
# batch_index 335,loss 2.582191
# batch_index 336,loss 2.725473
# batch_index 337,loss 2.700363
# batch_index 338,loss 2.938769
# batch_index 339,loss 2.808694
# batch_index 340,loss 2.709547
# batch_index 341,loss 3.074431
# batch_index 342,loss 2.734176
# batch_index 343,loss 2.885968
# batch_index 344,loss 2.693580
# batch_index 345,loss 2.794879
# batch_index 346,loss 2.764279
# batch_index 347,loss 2.760353
# batch_index 348,loss 2.614984
# batch_index 349,loss 2.885862
# batch_index 350,loss 2.480223
# batch_index 351,loss 3.045954
# batch_index 352,loss 2.729336
# batch_index 353,loss 2.701550
# batch_index 354,loss 2.512792
# batch_index 355,loss 2.799193
# batch_index 356,loss 2.688820
# batch_index 357,loss 3.021778
# batch_index 358,loss 2.772543
# batch_index 359,loss 2.729929
# batch_index 360,loss 2.871145
# batch_index 361,loss 2.816123
# batch_index 362,loss 2.925589
# batch_index 363,loss 2.744757
# batch_index 364,loss 2.878699
# batch_index 365,loss 2.664246
# batch_index 366,loss 2.712012
# batch_index 367,loss 2.996594
# batch_index 368,loss 2.646196
# batch_index 369,loss 2.464135
# batch_index 370,loss 2.794033
# batch_index 371,loss 2.861925
# batch_index 372,loss 2.761957
# batch_index 373,loss 3.013780
# batch_index 374,loss 2.710632
# batch_index 375,loss 2.855227
# batch_index 376,loss 2.604527
# batch_index 377,loss 2.951585
# batch_index 378,loss 2.546714
# batch_index 379,loss 2.734527
# batch_index 380,loss 2.631491
# batch_index 381,loss 2.700241
# batch_index 382,loss 2.877820
# batch_index 383,loss 2.763235
# batch_index 384,loss 2.613319
# batch_index 385,loss 2.818921
# batch_index 386,loss 2.794498
# batch_index 387,loss 2.694947
# batch_index 388,loss 2.569147
# batch_index 389,loss 2.695041
# batch_index 390,loss 2.784586
# batch_index 391,loss 2.732674
# batch_index 392,loss 2.898009
# batch_index 393,loss 2.730375
# batch_index 394,loss 2.960187
# batch_index 395,loss 2.923496
# batch_index 396,loss 2.619816
# batch_index 397,loss 3.098431
# batch_index 398,loss 2.779620
# batch_index 399,loss 3.066948
# batch_index 400,loss 2.580494
# batch_index 401,loss 2.574217
# batch_index 402,loss 2.631026
# batch_index 403,loss 2.439777
# batch_index 404,loss 2.625786
# batch_index 405,loss 2.975671
# batch_index 406,loss 2.845593
# batch_index 407,loss 2.736666
# batch_index 408,loss 2.774945
# batch_index 409,loss 2.526296
# batch_index 410,loss 2.696428
# batch_index 411,loss 2.660800
# batch_index 412,loss 2.707470
# batch_index 413,loss 2.780963
# batch_index 414,loss 2.672107
# batch_index 415,loss 2.882510
# batch_index 416,loss 2.550881
# batch_index 417,loss 2.868891
# batch_index 418,loss 2.773437
# batch_index 419,loss 2.732310
# batch_index 420,loss 2.720676
# batch_index 421,loss 3.038895
# batch_index 422,loss 2.554514
# batch_index 423,loss 2.533751
# batch_index 424,loss 2.732999
# batch_index 425,loss 2.805171
# batch_index 426,loss 2.640714
# batch_index 427,loss 2.492409
# batch_index 428,loss 2.303124
# batch_index 429,loss 2.567131
# batch_index 430,loss 2.694258
# batch_index 431,loss 2.621532
# batch_index 432,loss 2.587317
# batch_index 433,loss 2.658626
# batch_index 434,loss 2.762996
# batch_index 435,loss 2.783153
# batch_index 436,loss 2.825373
# batch_index 437,loss 2.451288
# batch_index 438,loss 2.449312
# batch_index 439,loss 2.619532
# batch_index 440,loss 2.473094
# batch_index 441,loss 2.705859
# batch_index 442,loss 2.676951
# batch_index 443,loss 2.439236
# batch_index 444,loss 2.569351
# batch_index 445,loss 2.775344
# batch_index 446,loss 2.628192
# batch_index 447,loss 2.438589
# batch_index 448,loss 2.852346
# batch_index 449,loss 2.557486
# batch_index 450,loss 2.410747
# batch_index 451,loss 2.738050
# batch_index 452,loss 2.811198
# batch_index 453,loss 2.678551
# batch_index 454,loss 2.745838
# batch_index 455,loss 2.636302
# batch_index 456,loss 2.421434
# batch_index 457,loss 2.840279
# batch_index 458,loss 2.498709
# batch_index 459,loss 2.722465
# batch_index 460,loss 2.728945
# batch_index 461,loss 2.679650
# batch_index 462,loss 2.658227
# batch_index 463,loss 2.702673
# batch_index 464,loss 2.642983
# batch_index 465,loss 2.713713
# batch_index 466,loss 2.651754
# batch_index 467,loss 2.519478
# batch_index 468,loss 2.701436
# batch_index 469,loss 2.675252
# batch_index 470,loss 2.732088
# batch_index 471,loss 2.501179
# batch_index 472,loss 2.938160
# batch_index 473,loss 2.647436
# batch_index 474,loss 2.523221
# batch_index 475,loss 2.717031
# batch_index 476,loss 2.676429
# batch_index 477,loss 2.432253
# batch_index 478,loss 2.960334
# batch_index 479,loss 2.925914
# batch_index 480,loss 2.820107
# batch_index 481,loss 2.575764
# batch_index 482,loss 2.469936
# batch_index 483,loss 2.565806
# batch_index 484,loss 2.474607
# batch_index 485,loss 2.653465
# batch_index 486,loss 2.808463
# batch_index 487,loss 2.471513
# batch_index 488,loss 2.991605
# batch_index 489,loss 2.589782
# batch_index 490,loss 2.836495
# batch_index 491,loss 2.700551
# batch_index 492,loss 2.576245
# batch_index 493,loss 2.419777
# batch_index 494,loss 2.425083
# batch_index 495,loss 2.819617
# batch_index 496,loss 2.597713
# batch_index 497,loss 2.509825
# batch_index 498,loss 2.517111
# batch_index 499,loss 2.647413
# batch_index 500,loss 2.599178
# batch_index 501,loss 2.616526
# batch_index 502,loss 2.491564
# batch_index 503,loss 2.366225
# batch_index 504,loss 2.669053
# batch_index 505,loss 2.827672
# batch_index 506,loss 2.499294
# batch_index 507,loss 2.231297
# batch_index 508,loss 2.393653
# batch_index 509,loss 2.261404
# batch_index 510,loss 2.465666
# batch_index 511,loss 2.705890
# batch_index 512,loss 2.247660
# batch_index 513,loss 2.942366
# batch_index 514,loss 2.703643
# batch_index 515,loss 2.641703
# batch_index 516,loss 2.160053
# batch_index 517,loss 2.583538
# batch_index 518,loss 2.240722
# batch_index 519,loss 2.840566
# batch_index 520,loss 2.631634
# batch_index 521,loss 2.845813
# batch_index 522,loss 2.453816
# batch_index 523,loss 2.516365
# batch_index 524,loss 2.429658
# batch_index 525,loss 2.594268
# batch_index 526,loss 2.860393
# batch_index 527,loss 2.942121
# batch_index 528,loss 2.533966
# batch_index 529,loss 2.703777
# batch_index 530,loss 2.657904
# batch_index 531,loss 2.961565
# batch_index 532,loss 2.292363
# batch_index 533,loss 2.573045
# batch_index 534,loss 2.462604
# batch_index 535,loss 2.610085
# batch_index 536,loss 2.404096
# batch_index 537,loss 2.464812
# batch_index 538,loss 2.529698
# batch_index 539,loss 2.743547
# batch_index 540,loss 2.707062
# batch_index 541,loss 2.778741
# batch_index 542,loss 2.774284
# batch_index 543,loss 2.340440
# batch_index 544,loss 2.752298
# batch_index 545,loss 2.613705
# batch_index 546,loss 2.249663
# batch_index 547,loss 2.624321
# batch_index 548,loss 2.589383
# batch_index 549,loss 2.442475
# batch_index 550,loss 2.802348
# batch_index 551,loss 2.605426
# batch_index 552,loss 2.433233
# batch_index 553,loss 2.397949
# batch_index 554,loss 2.604249
# batch_index 555,loss 2.657391
# batch_index 556,loss 2.468696
# batch_index 557,loss 2.846173
# batch_index 558,loss 2.325582
# batch_index 559,loss 2.517137
# batch_index 560,loss 2.332819
# batch_index 561,loss 2.484801
# batch_index 562,loss 2.687213
# batch_index 563,loss 2.627560
# batch_index 564,loss 2.634017
# batch_index 565,loss 2.585071
# batch_index 566,loss 2.675633
# batch_index 567,loss 2.806278
# batch_index 568,loss 2.470644
# batch_index 569,loss 2.635962
# batch_index 570,loss 2.518394
# batch_index 571,loss 2.579055
# batch_index 572,loss 2.664146
# batch_index 573,loss 2.544859
# batch_index 574,loss 2.742432
# batch_index 575,loss 2.543057
# batch_index 576,loss 2.526941
# batch_index 577,loss 2.822198
# batch_index 578,loss 2.481163
# batch_index 579,loss 2.304783
# batch_index 580,loss 2.506709
# batch_index 581,loss 2.261612
# batch_index 582,loss 2.704406
# batch_index 583,loss 2.825309
# batch_index 584,loss 2.484989
# batch_index 585,loss 2.553470
# batch_index 586,loss 2.463875
# batch_index 587,loss 2.398334
# batch_index 588,loss 2.415420
# batch_index 589,loss 2.702189
# batch_index 590,loss 2.508342
# batch_index 591,loss 2.534081
# batch_index 592,loss 2.222955
# batch_index 593,loss 2.670394
# batch_index 594,loss 2.632020
# batch_index 595,loss 2.543357
# batch_index 596,loss 2.414466
# batch_index 597,loss 2.272964
# batch_index 598,loss 2.604752
# batch_index 599,loss 2.210675
# batch_index 600,loss 2.660165
# batch_index 601,loss 2.361007
# batch_index 602,loss 2.603618
# batch_index 603,loss 2.370827
# batch_index 604,loss 2.761415
# batch_index 605,loss 2.583749
# batch_index 606,loss 2.365208
# batch_index 607,loss 2.312877
# batch_index 608,loss 2.438676
# batch_index 609,loss 2.713892
# batch_index 610,loss 2.457597
# batch_index 611,loss 2.703094
# batch_index 612,loss 2.475710
# batch_index 613,loss 2.914369
# batch_index 614,loss 2.562662
# batch_index 615,loss 2.459529
# batch_index 616,loss 2.555723
# batch_index 617,loss 2.571270
# batch_index 618,loss 2.708070
# batch_index 619,loss 2.477644
# batch_index 620,loss 2.782342
# batch_index 621,loss 2.530661
# batch_index 622,loss 2.255437
# batch_index 623,loss 2.285606
# batch_index 624,loss 2.584347
# batch_index 625,loss 2.396585
# batch_index 626,loss 2.289004
# batch_index 627,loss 2.421703
# batch_index 628,loss 2.631849
# batch_index 629,loss 2.717657
# batch_index 630,loss 2.226207
# batch_index 631,loss 2.296712
# batch_index 632,loss 2.399806
# batch_index 633,loss 2.622981
# batch_index 634,loss 2.652207
# batch_index 635,loss 2.521688
# batch_index 636,loss 2.576956
# batch_index 637,loss 2.261998
# batch_index 638,loss 2.713586
# batch_index 639,loss 2.618842
# batch_index 640,loss 2.501264
# batch_index 641,loss 2.645148
# batch_index 642,loss 2.645577
# batch_index 643,loss 2.408884
# batch_index 644,loss 2.375747
# batch_index 645,loss 2.438865
# batch_index 646,loss 2.789938
# batch_index 647,loss 3.011117
# batch_index 648,loss 2.487336
# batch_index 649,loss 2.726288
# batch_index 650,loss 2.495420
# batch_index 651,loss 2.774407
# batch_index 652,loss 2.695887
# batch_index 653,loss 2.506829
# batch_index 654,loss 2.857797
# batch_index 655,loss 2.538853
# batch_index 656,loss 2.298414
# batch_index 657,loss 2.509255
# batch_index 658,loss 2.388254
# batch_index 659,loss 2.815663
# batch_index 660,loss 2.321657
# batch_index 661,loss 2.558819
# batch_index 662,loss 2.388516
# batch_index 663,loss 2.578378
# batch_index 664,loss 2.517048
# batch_index 665,loss 2.297461
# batch_index 666,loss 2.359032
# batch_index 667,loss 2.539819
# batch_index 668,loss 2.403618
# batch_index 669,loss 2.409972
# batch_index 670,loss 2.819754
# batch_index 671,loss 2.637058
# batch_index 672,loss 2.436469
# batch_index 673,loss 2.167827
# batch_index 674,loss 2.374899
# batch_index 675,loss 2.361450
# batch_index 676,loss 2.620948
# batch_index 677,loss 2.465634
# batch_index 678,loss 1.915783
# batch_index 679,loss 2.266349
# batch_index 680,loss 2.624712
# batch_index 681,loss 2.517761
# batch_index 682,loss 2.590792
# batch_index 683,loss 2.679239
# batch_index 684,loss 2.374515
# batch_index 685,loss 2.445399
# batch_index 686,loss 2.206407
# batch_index 687,loss 2.362674
# batch_index 688,loss 2.558939
# batch_index 689,loss 2.513386
# batch_index 690,loss 2.160435
# batch_index 691,loss 2.486867
# batch_index 692,loss 1.940253
# batch_index 693,loss 2.511782
# batch_index 694,loss 2.686353
# batch_index 695,loss 2.767130
# batch_index 696,loss 2.645030
# batch_index 697,loss 2.303542
# batch_index 698,loss 2.140957
# batch_index 699,loss 2.537588
# batch_index 700,loss 2.181294
# batch_index 701,loss 2.198786
# batch_index 702,loss 2.483618
# batch_index 703,loss 2.499956
# batch_index 704,loss 2.544386
# batch_index 705,loss 2.328792
# batch_index 706,loss 2.651723
# batch_index 707,loss 2.367997
# batch_index 708,loss 2.840915
# batch_index 709,loss 2.502266
# batch_index 710,loss 2.336524
# batch_index 711,loss 2.411086
# batch_index 712,loss 2.755031
# batch_index 713,loss 2.393422
# batch_index 714,loss 2.464395
# batch_index 715,loss 2.742375
# batch_index 716,loss 2.416876
# batch_index 717,loss 2.498677
# batch_index 718,loss 2.303403
# batch_index 719,loss 2.875398
# batch_index 720,loss 2.529227
# batch_index 721,loss 2.195433
# batch_index 722,loss 2.457187
# batch_index 723,loss 2.532068
# batch_index 724,loss 2.518509
# batch_index 725,loss 2.713557
# batch_index 726,loss 2.478776
# batch_index 727,loss 2.467374
# batch_index 728,loss 2.357531
# batch_index 729,loss 2.870521
# batch_index 730,loss 2.157677
# batch_index 731,loss 2.722142
# batch_index 732,loss 2.249448
# batch_index 733,loss 2.281631
# batch_index 734,loss 2.369098
# batch_index 735,loss 2.874764
# batch_index 736,loss 2.120661
# batch_index 737,loss 2.598127
# batch_index 738,loss 2.722024
# batch_index 739,loss 2.185932
# batch_index 740,loss 2.882321
# batch_index 741,loss 2.561819
# batch_index 742,loss 2.509788
# batch_index 743,loss 2.424585
# batch_index 744,loss 2.426820
# batch_index 745,loss 2.429346
# batch_index 746,loss 2.705343
# batch_index 747,loss 2.224190
# batch_index 748,loss 2.616760
# batch_index 749,loss 2.470562
# batch_index 750,loss 2.529146
# batch_index 751,loss 2.544014
# batch_index 752,loss 2.594941
# batch_index 753,loss 2.363165
# batch_index 754,loss 2.525440
# batch_index 755,loss 2.467426
# batch_index 756,loss 2.592376
# batch_index 757,loss 2.340034
# batch_index 758,loss 2.826643
# batch_index 759,loss 3.009488
# batch_index 760,loss 2.551034
# batch_index 761,loss 2.610284
# batch_index 762,loss 2.312761
# batch_index 763,loss 2.281985
# batch_index 764,loss 2.313153
# batch_index 765,loss 2.780507
# batch_index 766,loss 2.344032
# batch_index 767,loss 2.650889
# batch_index 768,loss 2.322387
# batch_index 769,loss 2.585958
# batch_index 770,loss 2.242257
# batch_index 771,loss 2.691892
# batch_index 772,loss 2.645907
# batch_index 773,loss 2.417142
# batch_index 774,loss 2.495377
# batch_index 775,loss 2.352437
# batch_index 776,loss 2.350692
# batch_index 777,loss 2.413482
# batch_index 778,loss 2.603005
# batch_index 779,loss 2.211805
# batch_index 780,loss 2.291231
# batch_index 781,loss 2.484417
# batch_index 782,loss 2.437085
# batch_index 783,loss 2.218523
# batch_index 784,loss 2.655912
# batch_index 785,loss 2.755254
# batch_index 786,loss 2.151619
# batch_index 787,loss 2.144336
# batch_index 788,loss 2.409471
# batch_index 789,loss 2.471203
# batch_index 790,loss 2.342804
# batch_index 791,loss 2.516874
# batch_index 792,loss 2.549562
# batch_index 793,loss 2.306685
# batch_index 794,loss 2.690763
# batch_index 795,loss 2.313696
# batch_index 796,loss 2.460784
# batch_index 797,loss 2.179351
# batch_index 798,loss 2.414817
# batch_index 799,loss 2.291672
# batch_index 800,loss 2.328656
# batch_index 801,loss 2.384841
# batch_index 802,loss 2.391240
# batch_index 803,loss 2.215919
# batch_index 804,loss 2.639882
# batch_index 805,loss 2.732178
# batch_index 806,loss 2.579921
# batch_index 807,loss 2.474400
# batch_index 808,loss 2.544929
# batch_index 809,loss 2.188731
# batch_index 810,loss 2.562268
# batch_index 811,loss 2.706180
# batch_index 812,loss 2.577018
# batch_index 813,loss 2.460477
# batch_index 814,loss 2.263488
# batch_index 815,loss 2.287795
# batch_index 816,loss 2.365889
# batch_index 817,loss 2.349777
# batch_index 818,loss 2.622397
# batch_index 819,loss 2.333928
# batch_index 820,loss 2.684724
# batch_index 821,loss 2.854827
# batch_index 822,loss 2.686780
# batch_index 823,loss 2.203489
# batch_index 824,loss 2.559591
# batch_index 825,loss 2.579637
# batch_index 826,loss 2.396679
# batch_index 827,loss 2.452386
# batch_index 828,loss 2.302875
# batch_index 829,loss 2.298754
# batch_index 830,loss 2.325796
# batch_index 831,loss 2.631603
# batch_index 832,loss 2.386598
# batch_index 833,loss 2.205257
# batch_index 834,loss 2.409565
# batch_index 835,loss 2.434512
# batch_index 836,loss 2.769735
# batch_index 837,loss 2.530623
# batch_index 838,loss 2.298646
# batch_index 839,loss 2.419894
# batch_index 840,loss 2.230025
# batch_index 841,loss 2.582532
# batch_index 842,loss 2.341814
# batch_index 843,loss 2.485786
# batch_index 844,loss 2.677834
# batch_index 845,loss 2.499001
# batch_index 846,loss 2.598781
# batch_index 847,loss 2.531510
# batch_index 848,loss 2.401077
# batch_index 849,loss 2.344452
# batch_index 850,loss 2.457129
# batch_index 851,loss 2.557630
# batch_index 852,loss 2.178030
# batch_index 853,loss 2.123830
# batch_index 854,loss 2.491939
# batch_index 855,loss 2.617218
# batch_index 856,loss 2.369057
# batch_index 857,loss 2.147678
# batch_index 858,loss 2.616504
# batch_index 859,loss 2.773966
# batch_index 860,loss 2.615988
# batch_index 861,loss 2.473736
# batch_index 862,loss 2.225745
# batch_index 863,loss 2.480588
# batch_index 864,loss 2.537205
# batch_index 865,loss 2.422515
# batch_index 866,loss 2.252100
# batch_index 867,loss 2.448277
# batch_index 868,loss 2.248397
# batch_index 869,loss 2.274605
# batch_index 870,loss 2.238284
# batch_index 871,loss 2.698900
# batch_index 872,loss 2.434543
# batch_index 873,loss 2.404630
# batch_index 874,loss 2.751636
# batch_index 875,loss 2.459280
# batch_index 876,loss 2.456449
# batch_index 877,loss 2.537849
# batch_index 878,loss 2.363940
# batch_index 879,loss 2.370839
# batch_index 880,loss 2.733460
# batch_index 881,loss 2.443188
# batch_index 882,loss 2.253229
# batch_index 883,loss 2.421495
# batch_index 884,loss 2.222014
# batch_index 885,loss 2.592570
# batch_index 886,loss 2.422503
# batch_index 887,loss 2.669372
# batch_index 888,loss 2.426400
# batch_index 889,loss 2.468746
# batch_index 890,loss 2.173697
# batch_index 891,loss 2.592428
# batch_index 892,loss 2.233578
# batch_index 893,loss 2.215111
# batch_index 894,loss 2.609104
# batch_index 895,loss 2.620125
# batch_index 896,loss 1.938348
# batch_index 897,loss 2.658038
# batch_index 898,loss 2.581507
# batch_index 899,loss 2.281122
# batch_index 900,loss 2.087354
# batch_index 901,loss 2.412661
# batch_index 902,loss 2.527185
# batch_index 903,loss 2.261638
# batch_index 904,loss 2.419666
# batch_index 905,loss 2.265474
# batch_index 906,loss 2.358582
# batch_index 907,loss 2.344347
# batch_index 908,loss 2.317758
# batch_index 909,loss 2.183486
# batch_index 910,loss 2.712034
# batch_index 911,loss 2.472188
# batch_index 912,loss 2.561420
# batch_index 913,loss 2.348633
# batch_index 914,loss 2.504014
# batch_index 915,loss 2.473347
# batch_index 916,loss 2.775262
# batch_index 917,loss 2.543620
# batch_index 918,loss 2.226343
# batch_index 919,loss 2.162975
# batch_index 920,loss 2.387012
# batch_index 921,loss 2.384745
# batch_index 922,loss 2.364145
# batch_index 923,loss 2.594074
# batch_index 924,loss 2.459587
# batch_index 925,loss 2.441096
# batch_index 926,loss 2.384488
# batch_index 927,loss 2.343441
# batch_index 928,loss 2.483665
# batch_index 929,loss 2.490155
# batch_index 930,loss 2.593235
# batch_index 931,loss 2.366097
# batch_index 932,loss 2.199077
# batch_index 933,loss 2.212825
# batch_index 934,loss 2.465606
# batch_index 935,loss 2.539538
# batch_index 936,loss 2.440287
# batch_index 937,loss 2.462582
# batch_index 938,loss 2.638893
# batch_index 939,loss 2.746728
# batch_index 940,loss 2.539755
# batch_index 941,loss 2.648580
# batch_index 942,loss 2.284125
# batch_index 943,loss 2.586799
# batch_index 944,loss 2.420268
# batch_index 945,loss 2.625935
# batch_index 946,loss 2.706188
# batch_index 947,loss 2.658774
# batch_index 948,loss 2.460898
# batch_index 949,loss 2.254281
# batch_index 950,loss 2.768092
# batch_index 951,loss 2.132972
# batch_index 952,loss 2.260188
# batch_index 953,loss 2.682911
# batch_index 954,loss 2.395158
# batch_index 955,loss 2.761409
# batch_index 956,loss 2.398848
# batch_index 957,loss 2.091479
# batch_index 958,loss 2.597808
# batch_index 959,loss 2.014900
# batch_index 960,loss 2.443233
# batch_index 961,loss 2.389274
# batch_index 962,loss 2.202180
# batch_index 963,loss 2.400206
# batch_index 964,loss 2.439329
# batch_index 965,loss 2.478294
# batch_index 966,loss 2.387493
# batch_index 967,loss 2.924807
# batch_index 968,loss 2.209454
# batch_index 969,loss 2.036394
# batch_index 970,loss 2.369922
# batch_index 971,loss 2.324166
# batch_index 972,loss 2.286396
# batch_index 973,loss 2.337613
# batch_index 974,loss 2.356719
# batch_index 975,loss 2.811875
# batch_index 976,loss 2.641380
# batch_index 977,loss 2.562985
# batch_index 978,loss 2.431250
# batch_index 979,loss 2.558985
# batch_index 980,loss 2.687266
# batch_index 981,loss 2.378912
# batch_index 982,loss 2.495171
# batch_index 983,loss 2.253020
# batch_index 984,loss 2.459717
# batch_index 985,loss 2.081721
# batch_index 986,loss 2.280545
# batch_index 987,loss 2.641068
# batch_index 988,loss 2.565588
# batch_index 989,loss 2.394127
# batch_index 990,loss 2.400607
# batch_index 991,loss 2.437881
# batch_index 992,loss 2.448917
# batch_index 993,loss 2.236003
# batch_index 994,loss 2.383839
# batch_index 995,loss 2.311390
# batch_index 996,loss 2.243503
# batch_index 997,loss 2.464043
# batch_index 998,loss 2.287612
# batch_index 999,loss 2.563694

# %%
X_, _ = data_loader.get_batch(seq_length, 1)
for diversity in [0.2, 0.5, 1.0, 1.2]:      # 丰富度（即temperature）分别设置为从小到大的 4 个值
    X = X_
    print("diversity %f:" % diversity)
    for t in range(400):
        y_pred = model.predict(X, diversity)    # 预测下一个字符的编号
        print(data_loader.indices_char[y_pred[0]], end='', flush=True)  # 输出预测的字符
        X = np.concatenate([X[:, 1:], np.expand_dims(y_pred, axis=1)], axis=-1)     # 将预测的字符接在输入 X 的末尾，并截断 X 的第一个字符，以保证 X 的长度不变
    print("\n")
# Out:
# diversity 0.200000:
#  the the the the the the the the the the the the the the the the the the the the the the the the the the the core the the the the the the the the the ther the the the the the the ther the the the the the the the the the the the the the the the the the the the the the the the the ther the the the the the the the tore the the the the the the the the the the the the the the the the the the the the th
#
# diversity 0.500000:
#  in the the tore the thevenit ond the irinite the the the the core fore hererty be the rores ent the gnrin tuling thicant on the the the pres or the the the the the srether the nor verules in the the the mon the tere of manenan the the eth the an treres the the thit ther ent ind rather pretn ther of the heren the indery the coreres the
# reratire ther thit tise anders sont cinise
# the tor the prerenc
#
# diversity 1.000000:
#  pore gad vedd, de iple boremo onlo
# gis if vers therceen aft5rindy init or ted iele inct perted mongiup,, anlencb
# ctd-yfetetns
# r mulivary
# ort onf orvelad,
#
# rone sokf inte kfall ses]ilkre ok
# gn or
#
# winls soldis oncondint .skscjitvor atsy it toc, apst an rellgr for ong and tof nclperirt-s"tre-upty, hed syecedtty-lt alt
# torenr trd  cos: ofored c wurwicr, in:eref0t ind thaspaqu
# tay inghiciaingy slice
#
#
# diversity 1.200000:
#  atth
# iptpith' is sa thinwer
# ?fyilisg to is the niacay bro vh pnmapoegerirs -foncey. astutclriiv the  rers ststhene trdr syr
# e outilvorbt lrer t, cravive,
# thesd wip-
# nttt rs rrertossacdstaoed, 4onet. tos toxesorsind domcsipure anc owlely frqnlithhy depprebp, ;ed rhciga"y!
# tdevim?. rnt dtliets. frl
# atirishedlerid d rr rilay g, d tpen whelar"
# coverelulegw-mprtitile corer
# . uonaunesc1ry sourerssat, i
